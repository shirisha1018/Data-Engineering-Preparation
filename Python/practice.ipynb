# %%
2 + 3
# Out:
# 5

# %%
9 - 5
# Out:
# 4

# %%
5*8
# Out:
# 40

# %%
7+7-5
# Out:
# 9

# %%
7**3
# Out:
# 343

# %%
17%4
# Out:
# 1

# %%
' shirisha '
# Out:
# ' shirisha '

# %%
print(' shirisha ')
# Out:
#  shirisha

# %%
print(" shirisha's laptop ")
# Out:
#  shirisha's laptop

# %%
print('shirisha\s " laptop "' )
# Out:
# shirisha\s " laptop "

# %%
print('c:\docs\shirisha')
# Out:
# c:\docs\shirisha

# %%
print(r'c:\docs\nshirisha')
# Out:
# c:\docs\nshirisha

# %%
print('c:\docs\nshirisha')
# Out:
# c:\docs
# shirisha

# %%
g=7

# %%
g
# Out:
# 7

# %%
f=9

# %%
f+g
# Out:
# 16

# %%
name='shirisha'

# %%
name
# Out:
# 'shirisha'

# %%
name+'goud'
# Out:
# 'shirishagoud'

# %%
name[6]
# Out:
# 'h'

# %%
name[-4]
# Out:
# 'i'

# %%
name[1:6]
# Out:
# 'hiris'

# %%
name[3:]
# Out:
# 'risha'

# %%
nums=[3,4,5,6,7,8]

# %%
nums
# Out:
# [3, 4, 5, 6, 7, 8]

# %%
nums[1]
# Out:
# 4

# %%
nums[3]
# Out:
# 6

# %%
nums[3:5]
# Out:
# [6, 7]

# %%
nums[-2]
# Out:
# 7

# %%
tup=( 4,5,6,7,8)

# %%
tup[3]
# Out:
# 7

# %%
s={ 4,5,6,7,8,9}

# %%
s
# Out:
# {4, 5, 6, 7, 8, 9}

# %%
if true:
    print( "im right" )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 if true:
#       2     print( "im right" )
#
# NameError: name 'true' is not defined

# %%
if true:
    print("im right")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 if true:
#       2     print("im right")
#
# NameError: name 'true' is not defined

# %%
x=14
r=x%3


if r==0:
   print("Even")
   if x>5:
        print("great")
if r==1:
   print("odd")

print("bye")
# Out:
# bye

# %%
x=2

if(x==1):
    print("one")

elif (x==2):
    print("two")

elif(x==3):
    print("three")
# Out:
# two

# %% [markdown]
# **Practice Questions**

# %%
# Part 1: Variables & Data Types
# Problem 1: Create a variable named city and assign the name of your hometown to it as a string. Use the print() function to display it.

# Problem 2: Create a variable named price with a value of 99.99. Print the variable and write a comment above it guessing its data type (Integer, Float, or String).

# Problem 3: Create a variable named items_count and store the number 5 in it. On the next line, change the value of items_count to 10. Print items_count to see which value Python kept.

# Problem 4: Create two variables, first_name and last_name, and store your names in them. Use the + operator to combine them together and print your full name.

# 🧮 Part 2: Simple Math with Variables
# Problem 5: Create a variable length = 20 and width = 10. Create a third variable called area that multiplies length and width together. Print the area. (Hint: Use * for multiplication).

# Problem 6: Look at this code without running it first. What do you think it will print? Write your guess down, then run it in your notebook to check:

# Python
# num1 = "100"
# num2 = "200"
# print(num1 + num2)
# 🔀 Part 3: Simple If-Else Decisions
# Problem 7: Create a variable named temperature and set it to 35. Write an if-else statement:

# If the temperature is greater than 30, print "It is a hot day!"

# Otherwise, print "The weather is pleasant."

# Problem 8: Create a variable named my_number and assign any whole number to it. Write an if-else statement to check if the number is greater than or equal to 0. If it is, print "Positive or Zero". If it isn't, print "Negative".

# Problem 9: Create a variable named is_logged_in and set it to True. Write an if-else block:

# If is_logged_in is True, print "Welcome back to your dashboard!"

# Else, print "Please log in."

# Problem 10: Create a variable named budget and set it to 500. Create another variable named expense and set it to 600. Write an if-else statement to check if expense is greater than budget. If it is, print "Over budget!". Otherwise, print "Safe to spend!".

# %%
city="kharmanghat" 
print(city)
# Out:
# kharmanghat

# %%
price=99.99 
print(type(price))
# Out:
# <class 'float'>

# %%
items_count=5
items_count
items_count = 10
print(items_count)
# Out:
# 10

# %%
first_name='shirisha'
last_name='goud'
first_name + last_name
# Out:
# 'shirishagoud'

# %%
length=20
width=10
area=(length*width)
print(area)
# Out:
# 200

# %%
num1="100" 
num2= "200"
print(num1+num2)
# Out:
# 100200

# %%
temperature=35
if temperature>30:
    print("it is a hot day")

else:
    print("the weather is pleasant")
# Out:
# it is a hot day

# %%
my_number=18
if my_number>=0:
    print("positive or zero")

else:
    print("negative")
# Out:
# positive or zero

# %%
is_logged_in = True

if is_logged_in == True:
    print("Welcome back to your dashboard!")
else:
    print("Please log in")
# Out:
# Welcome back to your dashboard!

# %%
budget=500
expense=600
if expense>budget:
    print("over budget")

else:
    print("safe to spend")
# Out:
# over budget
